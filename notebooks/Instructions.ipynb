# %% [markdown]
# # ToDo: update this list
#
# Requirements:
# - snowballing
#
# ## Search Work / Bibtex
#
# - Database Work to Bibtex
# - Notebook: [../notebooks/Bibtex.SearchWork.ipynb](../notebooks/Bibtex.SearchWork.ipynb)
# - Extra1: Check if all snowballed approaches appear in the bibtex
# - Extra2: Look for unmatched work
# - Extra3: Recreate Bibtex
#
# ## Approaches Page
#
# - Notebook: [../notebooks/ApproachesHTML.ipynb](../notebooks/ApproachesHTML.ipynb)
#
#
# ## fig:lifecycle
#
# - Source: [figs/csur.pptx](figs/csur.pptx)
# - Final: [figs/lifecycle.png](figs/lifecycle.png)
#
# ## alg:polish_eval
#
# - Source/Final: [figs/polish_eval.py](figs/polish_eval.py)
#
# ## fig:classification
#
# - Source: [figs/csur.pptx](figs/csur.pptx)
# - Final: [figs/provenance_classification.png](figs/provenance_classification.png)
#
# ## fig:strategies
#
# - Source: [figs/csur.pptx](figs/csur.pptx)
# - Final: [figs/strategies.png](figs/strategies.png)
#
# ## fig:taxonomy
#
# - Source: ../website/taxonomy.{[html](../website/taxonomy.html),[csv](../website/taxonomy.csv)}
# - Extra: [../website/d3.v4.min.js](../website/d3.v4.min.js); [../website/downloadSVG.js](../website/downloadSVG.js);
# - Steps:
#   1. Load HTML
#   2. Download SVG and put it into ../website folder
#   3. Run `inkscape -D -z --file=taxonomy.svg --export-pdf=../csur/figs/taxonomy.pdf`
# - Final: [figs/taxonomy.pdf](figs/taxonomy.pdf)
#
# ## fig:snowballing
#
# - Requirements: [Graphviz](http://www.graphviz.org/), [ProvToolbox](http://lucmoreau.github.io/ProvToolbox/)
# - Source: [../notebooks/SnowballingProvenance.ipynb](../notebooks/SnowballingProvenance.ipynb)
# - Steps: Run notebook
# - Final: [figs/snowballing.png](figs/snowballing.png)
#
# ## fig:citationgraph
#
# - Source: [../notebooks/CitationGraph.ipynb](../notebooks/CitationGraph.ipynb)
#
# ### Header
#
# - Source: [../website/selected.html](../website/selected.html)
# - Steps:
#   1. Load HTML
#   2. Take Screenshot
#   3. Copy header on paint
# - Final: [figs/citationgraph.png](figs/citationgraph.png)
#
# ### Content
#
# - Source: [../notebooks/CitationGraph.ipynb](../notebooks/CitationGraph.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/citationgraph.pdf](figs/citationgraph.pdf)
#
# ## fig:place
#
# - Source: [../notebooks/Place.ipynb](../notebooks/Place.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/place.pdf](figs/place.pdf)
#
# ## tab:provenance-support
#
# - Source: [../notebooks/Goals.ipynb](../notebooks/Goals.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/goals.tex](figs/goals.tex)
#
# ## tab:language-support
#
# - Source: [../notebooks/Languages.ipynb](../notebooks/Languages.ipynb)\
# - Steps: Run notebook. Modify text
# - Final: [figs/script_languages.tex](figs/script_languages.tex)
#
# ## fig:types_x_goals
#
# - Source: [../notebooks/BubblePlot.ipynb](../notebooks/BubblePlot.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/types_x_goals.pdf](figs/types_x_goals.pdf)
#
# ## tab:script-collection
#
# - Source: [../notebooks/Collection.ipynb](../notebooks/Collection.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/script_collection.tex](figs/script_collection.tex)
#
# ## fig:storage_x_goals
#
# - Source: [../notebooks/BubblePlot.ipynb](../notebooks/BubblePlot.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/storage_x_goals.pdf](figs/storage_x_goals.pdf)
#
#
# ## fig:file_database_x_goals
#
# - Source: [../notebooks/BubblePlot.ipynb](../notebooks/BubblePlot.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/file_x_goals.pdf](figs/file_x_goals.pdf)
# - Final: [figs/database_x_goals.pdf](figs/database_x_goals.pdf)
#
#
# ## fig:storage_x_distribution
#
# - Source: [../notebooks/BubblePlot.ipynb](../notebooks/BubblePlot.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/storage_x_distribution.pdf](figs/storage_x_distribution.pdf)
#
# ## fig:visualization_x_goals
#
# - Source: [../notebooks/BubblePlot.ipynb](../notebooks/BubblePlot.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/visualization_x_goals.pdf](figs/visualization_x_goals.pdf)
#
# ## fig:query_x_goals
#
# - Source: [../notebooks/BubblePlot.ipynb](../notebooks/BubblePlot.ipynb)
# - Steps: Run notebook. Modify text
# - Final: [figs/visualization_x_goals.pdf](figs/query_x_goals.pdf)
