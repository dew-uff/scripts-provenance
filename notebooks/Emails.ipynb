# %%
import os, sys, re
from functools import partial

import pandas as pd
import numpy as np

from bibtexparser.latexenc import string_to_latex

sys.path.insert(1, os.path.join(sys.path[0], '..'))

import database
from snowballing.operations import load_work_map_all_years, work_to_bibtex, reload
from snowballing.operations import match_bibtex_to_work
from snowballing.approaches import get_approaches, name, wlatex_name, wcitea
reload()

all_approaches = get_approaches()
script = [(a, m) for a, m in all_approaches if not m["binary"]]
binary = [(a, m) for a, m in all_approaches if m["binary"]]
len(script)
# Out:
# 27

# %%
with open('../../csur/bibliography.bib') as bibtex_file:
    bibtex_str = bibtex_file.read()

matched = match_bibtex_to_work(bibtex_str.split("%Entries")[-1])
works = dict(map(reversed, matched))
latex_name = partial(wlatex_name, works=works)
citea = partial(wcitea, works=works)

# %%
TEMPLATE = """
TITLE: {tname} – Could you check if the following information is correct?
TO: {emails}
CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br

Dear {authors},

We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the 
state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would 
also like to include {name} in this survey{middle}

To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list 
of features. We got these features based on {papers} but want to make sure we got everything
correctly. We would highly appreciate if you could check our classification and make corrections when needed.
Please send your answer before {date}. This would allow us to include your comments in our paper.

Please, note that this is not a competition and we do not intend to rank the included systems.

Collection
        ({annotations}) Annotations
                Placement: ({internal}) Internal; ({external}) External
                Extraction: ({extract_parseable}) Parseable; ({extract_execution}) Execution 
                Inclusiveness: ({inclusive}) Inclusive; ({exclusive}) Exclusive
                Target: ({target_definition}) Definition; ({target_provenance}) Provenance
                Necessity: ({optional}) Optional; ({mandatory}) Mandatory
        ({execution}) Execution 
                ({passive_monitoring}) Passive Monitoring
                ({overriding}) Overriding
                ({post_mortem}) Post-Mortem
                ({instrumentation}) Instrumentation
        ({deployment}) Deployment 
                ({before}) Before
                ({during}) During
        ({definition}) Definition 
                How: ({reading}) Reading; ({parsing}) Parsing
                When: ({static}) Static; ({dynamic}) Dynamic
Management
        ({storage}) Storage:
                ({database}) Database. Specify: {database_specify}
                ({memory}) Transient Memory
                ({file}) File. Specify: {file_specify}
        ({distribution}) Distribution
                ({file_dist}) File. Specify: {file_dist_specify}
                ({repository}) Repository
        ({reproducibility}) Reproducibility
        ({versioning}) Versioning
                ({trialid}) Trial ID
                ({sequence}) Sequence
                ({intention}) Intention
Analysis
        ({query}) Query
                ({generic}) Generic. Specify: {generic_specify}
                ({specific}) Specific. Specify: {specific_specify}
        ({visualization}) Visualization
                Place: ({place_internal}) Internal; ({place_external}) External
                Type: ({log}) Log; ({data}) Data; ({process}) Process; ({combined}) Combined
                Completeness: ({complete}) No Summarization; ({clustering}) Clustering; ({filtering}) Filtering
        ({diff}) Comparison:
                ({diff_data}) Data
                ({diff_provenance}) Provenance

A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins

Many thanks in advance!

All the best,
João Felipe Pimentel

{end}
"""

# %%
from database.groups import REPRODUCIBILITY
from database.groups import INTERNAL, EXTERNAL, PARSEABLE, EXECUTABLE, INCLUSIVE, EXCLUSIVE
from database.groups import MANDATORY, OPTIONAL, DEFINITION, PROVENANCE
from database.groups import PASSIVE_MONITORING, OVERRIDING, POST_MORTEM, INSTRUMENTATION
from database.groups import BEFORE_EXECUTION, DURING_EXECUTION
from database.groups import READING, PARSING, STATIC, DYNAMIC, ASKS
from database.groups import YES, NO
from database.groups import NOSQL, SHADOW_FILES, LOG, GRAPH_FILE, RELATIONAL_DB, FILE, WEB
from database.groups import FILE_SYSTEM, PACKAGE, LOGIC_FILE, INTEROPERABLE, PROPRIETARY
from database.groups import MEMORY, SOURCE, KEY_VALUE_DB, REPOSITORY, GRAPH_DB, VCS, CONTENT_DATABASE
from database.groups import TRIAL_ID, SEQUENCE, INTENTION, NO
from database.groups import YES, NO, PROCESS_VIEW, DATA_VIEW, COMBINED_VIEW, LOG_VIEW
from database.groups import CLUSTERING, FILTERING, DATA, PROVENANCE, INTEROPERABLE, PROPRIETARY
from database.groups import INTERNAL, EXTERNAL


storage_categories = {
    GRAPH_DB: 'Database',
    RELATIONAL_DB: 'Database',
    NOSQL: 'Database',
    MEMORY: 'Memory',
    CONTENT_DATABASE: 'File',
    LOG: 'File',
    INTEROPERABLE: 'File',
    LOGIC_FILE: 'File',
    GRAPH_FILE: 'File',
    PROPRIETARY: 'File',

    # Binary?
    KEY_VALUE_DB: 'Database',
    FILE_SYSTEM: 'File',
    PACKAGE: 'File',
    SHADOW_FILES: 'File',
}

distribution_categories = {
    MEMORY: 'Memory',
    CONTENT_DATABASE: 'File',
    LOG: 'File',
    INTEROPERABLE: 'File',
    LOGIC_FILE: 'File',
    GRAPH_FILE: 'File',
    PROPRIETARY: 'File',
    SOURCE: 'File',
    
    VCS: 'Remote',
    REPOSITORY: 'Remote',
    WEB: 'Remote',

    
    # Binary?
    FILE_SYSTEM: 'File',
    PACKAGE: 'File',
    SHADOW_FILES: 'File',  
}


def select(element, field):
    try:
        index = field.index(element)
        element = field[index]
        return "x"
    except ValueError:
        return "  "
    
def select_rev(element, categories, field):
    for value in field:
        if categories[value] == element:
            yield str(value)
    
def find(elements, abrevs, field):
    for element, abrev in zip(elements, abrevs):
        try:
            index = field.index(element)
            if (hasattr(element, "_star") and element._star is not None) or abrev is None:
                yield element
            yield abrev
        except ValueError:
            pass


def write_authors(authors):
    if len(authors) <= 2:
        return " and ".join(authors)
    authors = list(authors)
    return ", ".join(authors[:-1]) + ", and " + authors[-1]

def load_data(approach):
    work = approach.work
    
    refs = ", ".join(map(str, range(1, len(work) + 1)))
    references = []
    for i, w in enumerate(work):
        references.append(
            "[{}] {}. {}. {}, {}".format(
                i + 1, w.authors, w.name, w.place.name, w.year
            )
        )
    
    end = ""
    middle = "."
    tname = aname = name(approach)
    pname = "the {} paper".format(tname) + ("s" if len(work) > 1 else "")
    if approach.approach_name == "-":
        tname = "Provenance in Scripts"
        aname = pname = "your paper" + ("s" if len(work) > 1 else "")
        aname = "{} [{}]".format(aname, refs)
        middle = ":\n\n{}".format("\n".join(references))
    else:
        end = "References:\n{}".format("\n".join(references))
        pname = "{} [{}]".format(pname, refs)
    if getattr(approach, "to", None):
        authors = {
            " ".join(reversed(author.split(", "))): ""
            for author in approach.to.split(' and ')
        }
    else:
        authors = {
            " ".join(reversed(author.split(", "))): "" for w in work
            for author in w.authors.split(' and ')
        }
    
   
    return {
        'emails': approach.emails,
        'authors': write_authors(authors),
        'name': aname,
        'tname': tname,
        'papers': pname,
        'refs': refs,
        'end': end,
        'middle': middle,
        'date': 'December 14, 2018',
        # Collection
        ##
        'annotations': 'x' if meta["annotations"] else '  ',
        ### placement
        'internal': select(INTERNAL, meta["annotations"]),
        'external': select(EXTERNAL, meta["annotations"]),
        ### extraction
        'extract_parseable': select(PARSEABLE, meta["annotations"]),
        'extract_execution': select(EXECUTABLE, meta["annotations"]),
        ### inclusiveness
        'inclusive': select(INCLUSIVE, meta["annotations"]),
        'exclusive': select(EXCLUSIVE, meta["annotations"]),
        ### target
        'target_definition': select(DEFINITION, meta["annotations"]),
        'target_provenance': select(PROVENANCE, meta["annotations"]),
        ### necessity
        'optional': select(OPTIONAL, meta["annotations"]),
        'mandatory': select(MANDATORY, meta["annotations"]),
        ##
        'execution': 'x' if meta["execution"] else '  ',
        ###
        'passive_monitoring': select(PASSIVE_MONITORING, meta["execution"]),
        'overriding': select(OVERRIDING, meta["execution"]),
        'post_mortem': select(POST_MORTEM, meta["execution"]),
        'instrumentation': select(INSTRUMENTATION, meta["execution"]),
        ##
        'deployment': 'x' if meta["deployment"] else '  ',
        ###
        'before': select(BEFORE_EXECUTION, meta["deployment"]),
        'during': select(DURING_EXECUTION, meta["deployment"]),
        ##
        'definition': 'x' if meta["definition"] else '  ',
        ### how
        'reading': select(READING, meta["definition"]),
        'parsing': select(PARSING, meta["definition"]),
        ### when
        'static': select(STATIC, meta["definition"]),
        'dynamic': select(DYNAMIC, meta["definition"]),
        # Management
        ##
        'storage': 'x' if meta["storage"] else '  ',
        ###
        'database': select("Database", list(map(storage_categories.get, meta["storage"]))),
        'database_specify': ", ".join(select_rev("Database", storage_categories, meta["storage"])) or "__________",
        'memory': select("Memory", list(map(storage_categories.get, meta["storage"]))),
        'file': select("File", list(map(storage_categories.get, meta["storage"]))),
        'file_specify': ", ".join(select_rev("File", storage_categories, meta["storage"])) or "__________",
        ##
        'distribution': 'x' if meta["distribution"] else '  ',
        ###
        'file_dist': select("File", list(map(distribution_categories.get, meta["distribution"]))),
        'file_dist_specify': ", ".join(select_rev("File", distribution_categories, meta["distribution"])) or "__________",
        'repository': select("Repository", list(map(distribution_categories.get, meta["distribution"]))),
        ##
        'reproducibility': select(REPRODUCIBILITY, meta["supports"]),
        ##
        'versioning': 'x' if meta["evolution"] != NO else '  ',
        ###
        'trialid': 'x' if meta["evolution"] == TRIAL_ID else '  ',
        'sequence': 'x' if meta["evolution"] == SEQUENCE else '  ',
        'intention': 'x' if meta["evolution"] == INTENTION else '  ',
        # Analysis
        ##
        'query':  'x' if meta["generic_query_text"] or meta["specific_query_text"] else '  ',
        ###
        'generic': 'x' if meta["generic_query_text"] else '  ',
        'generic_specify': meta["generic_query_text"] or "__________",
        'specific': 'x' if meta["specific_query_text"] else '  ',
        'specific_specify': meta["specific_query_text"] or "__________",
        ##
        'visualization':  'x' if meta["visplace"] or meta["visualization"] else '  ',
        ### Place
        'place_internal': select(INTERNAL, meta["visplace"]),
        'place_external': select(EXTERNAL, meta["visplace"]),
        ### Type
        'log': select(LOG_VIEW, meta["visualization"]),
        'data': select(DATA_VIEW, meta["visualization"]),
        'process': select(PROCESS_VIEW, meta["visualization"]),
        'combined': select(COMBINED_VIEW, meta["visualization"]),
        ### Completeness
        'complete': 'x' if (meta["visplace"] or meta["visualization"]) and not meta["summarization"] else '  ',
        'clustering': select(CLUSTERING, meta["summarization"]),
        'filtering': select(FILTERING, meta["summarization"]),
        ##
        'diff': 'x' if meta["diff"] else '  ',
        ###
        'diff_data': select(DATA, meta["diff"]),
        'diff_provenance': select(PROVENANCE, meta["diff"]),
    }




for i, (approach, meta) in enumerate(script):
    data = load_data(approach)
    print(TEMPLATE.format(**data))
    with open("../../emails/{}-{}.txt".format(i, name(approach)).replace("*", "-"), "w") as f:
        f.write(TEMPLATE.format(**data))
# Out:
# TITLE: Astro-WISE – Could you check if the following information is correct?
# TO: Jmwebaze@gmail.com; d.r.boxhoorn@astro.rug.nl; valentyn@astro.rug.nl
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Johnson Mwebaze, Danny Boxhoorn, and Edwin Valentijn,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include Astro-WISE in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the Astro-WISE papers [1, 2] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (  ) Parsing
#                 When: (  ) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: Relational Database (Oracle)
#                 (  ) Transient Memory
#                 (  ) File. Specify: __________
#         (  ) Distribution
#                 (  ) File. Specify: __________
#                 (  ) Repository
#         (x) Reproducibility
#         (x) Versioning
#                 (  ) Trial ID
#                 (x) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: SQL
#                 (x) Specific. Specify: Functions, Web
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (x) Data; (  ) Process; (  ) Combined
#                 Completeness: (x) No Summarization; (  ) Clustering; (  ) Filtering
#         (x) Comparison:
#                 (  ) Data
#                 (x) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Mwebaze, Johnson and Boxhoorn, Danny and Valentijn, Edwin. Astro-wise: Tracing and using lineage for scientific data processing. International Conference on Network-Based Information Systems, 2009
# [2] Mwebaze, Johnson and Boxhoorn, Danny and Valentijn, Edwin. Dynamic Pipeline Changes in Scientific Data Processing. IEEE International Conference on e-Science, 2011
#
#
# TITLE: Provenance in Scripts – Could you check if the following information is correct?
# TO: rab@research.att.com; jmc@stat.stanford.edu
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Richard A Becker and John M Chambers,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include your paper [1] in this survey:
#
# [1] Becker, Richard A and Chambers, John M. Auditing of data analyses. SIAM Journal on Scientific and Statistical Computing, 1988
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on your paper but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (  ) Annotations
#                 Placement: (  ) Internal; (  ) External
#                 Extraction: (  ) Parseable; (  ) Execution
#                 Inclusiveness: (  ) Inclusive; (  ) Exclusive
#                 Target: (  ) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (  ) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (x) Overriding
#                 (  ) Post-Mortem
#                 (  ) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (x) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Proprietary
#         (x) Distribution
#                 (x) File. Specify: Proprietary, Source
#                 (  ) Repository
#         (x) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (  ) Generic. Specify: __________
#                 (x) Specific. Specify: Functions
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (x) Process; (  ) Combined
#                 Completeness: (x) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
#
#
#
# TITLE: Provenance in Scripts – Could you check if the following information is correct?
# TO: arsten@bochner.de; roland.gude@yoochoose.com; Andreas.Schreiber@dlr.de
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Carsten Bochner, Roland Gude, and Andreas Schreiber,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include your paper [1] in this survey:
#
# [1] Bochner, Carsten and Gude, Roland and Schreiber, Andreas. A python library for provenance recording and querying. International Provenance and Annotation Workshop, 2008
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on your paper but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (x) Deployment
#                 (  ) Before
#                 (x) During
#         (x) Definition
#                 How: (x) Reading; (  ) Parsing
#                 When: (  ) Static; (x) Dynamic
# Management
#         (  ) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (  ) File. Specify: __________
#         (x) Distribution
#                 (  ) File. Specify: __________
#                 (  ) Repository
#         (  ) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: XQuery, XPath
#                 (x) Specific. Specify: Web
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
#
#
#
# TITLE: CPL – Could you check if the following information is correct?
# TO: pmacko@eecs.harvard.edu; mseltzer@cs.ubc.ca
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Peter Macko and Margo Seltzer,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include CPL in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the CPL paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (  ) Annotations
#                 Placement: (  ) Internal; (  ) External
#                 Extraction: (  ) Parseable; (  ) Execution
#                 Inclusiveness: (  ) Inclusive; (  ) Exclusive
#                 Target: (  ) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (  ) Mandatory
#         (  ) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (  ) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (  ) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: Relational Database (MySQL, PostgreSQL), Graph Database (4store)
#                 (  ) Transient Memory
#                 (  ) File. Specify: __________
#         (x) Distribution
#                 (x) File. Specify: Proprietary (JSON)
#                 (  ) Repository
#         (  ) Reproducibility
#         (x) Versioning
#                 (x) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: SPARQL, SQL
#                 (x) Specific. Specify: Functions
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Macko, Peter and Seltzer, Margo. A General-Purpose Provenance Library. Workshop on the Theory and Practice of Provenance, 2012
#
#
# TITLE: CXXR – Could you check if the following information is correct?
# TO: C.A.Silles@kent.ac.uk; A.R.Runnalls@kent.ac.uk
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Chris A Silles, Andrew R Runnalls, Andrew Runnalls, Chris Silles, and Christopher Anthony Silles,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include CXXR in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the CXXR papers [1, 2, 3, 4, 5] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (  ) Annotations
#                 Placement: (  ) Internal; (  ) External
#                 Extraction: (  ) Parseable; (  ) Execution
#                 Inclusiveness: (  ) Inclusive; (  ) Exclusive
#                 Target: (  ) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (  ) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (x) Overriding
#                 (  ) Post-Mortem
#                 (  ) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (  ) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (x) Transient Memory
#                 (  ) File. Specify: __________
#         (  ) Distribution
#                 (  ) File. Specify: __________
#                 (  ) Repository
#         (  ) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (  ) Generic. Specify: __________
#                 (x) Specific. Specify: Functions
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Silles, Chris A and Runnalls, Andrew R. Provenance-awareness in R. International Provenance and Annotation Workshop, 2010
# [2] Runnalls, Andrew and Silles, Chris. Provenance tracking in R. International Provenance and Annotation Workshop, 2012
# [3] Silles, Christopher Anthony. Provenance-aware CXXR. Thesis, 2014
# [4] Runnalls, Andrew R and Silles, Chris A. CXXR: An ideas hatchery for future R development. Joint Statistical Meetings, 2011
# [5] Runnalls, Andrew R. Aspects of CXXR internals. Computational Statistics, 2011
#
#
# TITLE: Datatrack – Could you check if the following information is correct?
# TO: philip.eichinski@qut.edu.au; p.roe@qut.edu.au
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Philip Eichinski and Paul Roe,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include Datatrack in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the Datatrack paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (x) Provenance
#                 Necessity: (x) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (x) Deployment
#                 (  ) Before
#                 (x) During
#         (  ) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: VCS, Proprietary (CSV)
#         (x) Distribution
#                 (x) File. Specify: Proprietary (CSV)
#                 (  ) Repository
#         (  ) Reproducibility
#         (x) Versioning
#                 (  ) Trial ID
#                 (x) Sequence
#                 (  ) Intention
# Analysis
#         (  ) Query
#                 (  ) Generic. Specify: __________
#                 (  ) Specific. Specify: __________
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (x) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (x) Clustering; (  ) Filtering
#         (x) Comparison:
#                 (x) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Eichinski, Philip and Roe, Paul. Datatrack: An R package for managing data in a multi-stage experimental workflow. IEEE International Conference on e-Science, 2016
#
#
# TITLE: ES3 – Could you check if the following information is correct?
# TO: frew@bren.ucsb.edu; peter@eri.ucsb.edu; gjanee@ucop.edu
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear James Frew, Peter Slaughter, and Greg Janée,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include ES3 in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the ES3 papers [1, 2, 3, 4, 5, 6] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (  ) Annotations
#                 Placement: (  ) Internal; (  ) External
#                 Extraction: (  ) Parseable; (  ) Execution
#                 Inclusiveness: (  ) Inclusive; (  ) Exclusive
#                 Target: (  ) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (  ) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (x) Overriding
#                 (  ) Post-Mortem
#                 (  ) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (  ) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: NoSQL (XML Server)
#                 (  ) Transient Memory
#                 (  ) File. Specify: __________
#         (x) Distribution
#                 (x) File. Specify: Graph File (GraphML, GraphViz)
#                 (  ) Repository
#         (  ) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: XQuery
#                 (  ) Specific. Specify: __________
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (x) Combined
#                 Completeness: (x) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Frew, James and Metzger, Dominic and Slaughter, Peter. Automatic capture and reconstruction of computational provenance. Concurrency and Computation: Practice and Experience, 2008
# [2] Frew, James. Earth System Science Server (ES3): Local Infrastructure for Earth Science Product Management. Earth Science Technology Conference, 2004
# [3] Frew, James and Slaughter, Peter. Es3: A demonstration of transparent provenance for scientific computation. International Provenance and Annotation Workshop, 2008
# [4] Valeur, Håvar. Tracking the lineage of arbitrary processing sequences. Thesis, 2005
# [5] Frew, James and Janée, Greg and Slaughter, Peter. Automatic Provenance Collection and Publishing in a Science Data Production Environment -- Early Results. International Provenance and Annotation Workshop, 2010
# [6] Frew, James and Janée, Greg and Slaughter, Peter. Provenance-enabled automatic data publishing. Scientific and Statistical Database Management, 2011
#
#
# TITLE: ESSW – Could you check if the following information is correct?
# TO: frew@bren.ucsb.edu; rbose@columbia.edu
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear James Frew and Rajendra Bose,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include ESSW in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the ESSW paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (  ) Parsing
#                 When: (  ) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: Relational Database (MySQL)
#                 (  ) Transient Memory
#                 (x) File. Specify: Content Database
#         (x) Distribution
#                 (x) File. Specify: Graph File (GraphViz)
#                 (  ) Repository
#         (  ) Reproducibility
#         (x) Versioning
#                 (x) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: SQL
#                 (x) Specific. Specify: Web
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (x) Combined
#                 Completeness: (x) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Frew, James and Bose, Rajendra. Earth system science workbench: A data management infrastructure for earth science products. Scientific and Statistical Database Management, 2001
#
#
# TITLE: IncPy – Could you check if the following information is correct?
# TO: philip@pgbovine.net; engler@cs.stanford.edu
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Philip J Guo, Dawson R Engler, Dawson Engler, and Philip Jia Guo,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include IncPy in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the IncPy papers [1, 2, 3] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (x) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (x) Optional; (  ) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (x) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (x) Parsing
#                 When: (x) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Content Database
#         (x) Distribution
#                 (x) File. Specify: Content Database
#                 (  ) Repository
#         (  ) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (  ) Query
#                 (  ) Generic. Specify: __________
#                 (  ) Specific. Specify: __________
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (x) Comparison:
#                 (x) Data
#                 (x) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Guo, Philip J and Engler, Dawson R. Towards Practical Incremental Recomputation for Scientists: An Implementation for the Python Language. International Provenance and Annotation Workshop, 2010
# [2] Guo, Philip J and Engler, Dawson. Using automatic persistent memoization to facilitate data analysis scripting. ACM International Symposium on Software Testing and Analysis, 2011
# [3] Guo, Philip Jia. Software tools to facilitate research programming. Thesis, 2012
#
#
# TITLE: Lancet – Could you check if the following information is correct?
# TO: jlrstevens@gmail.com; me@marcoelver.com; jbednar@inf.ed.ac.uk
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Jean-Luc Richard Stevens, Marco Elver, and James A Bednar,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include Lancet in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the Lancet paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (x) Deployment
#                 (x) Before
#                 (  ) During
#         (x) Definition
#                 How: (  ) Reading; (x) Parsing
#                 When: (x) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Log
#         (x) Distribution
#                 (x) File. Specify: Log
#                 (  ) Repository
#         (x) Reproducibility
#         (x) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (x) Intention
# Analysis
#         (  ) Query
#                 (  ) Generic. Specify: __________
#                 (  ) Specific. Specify: __________
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (x) Comparison:
#                 (x) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Stevens, Jean-Luc Richard and Elver, Marco and Bednar, James A. An automated and reproducible workflow for running and analyzing neural simulations using Lancet and IPython Notebook. Frontiers in Neuroinformatics, 2013
#
#
# TITLE: Magni – Could you check if the following information is correct?
# TO: cso@es.aau.dk; tha@es.aau.dk; tola@adm.aau.dk
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Christian Schou Oxvig, Thomas Arildsen, and Torben Larsen,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include Magni in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the Magni paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (x) Deployment
#                 (  ) Before
#                 (x) During
#         (x) Definition
#                 How: (x) Reading; (  ) Parsing
#                 When: (x) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Proprietary (JSON, HDF5)
#         (x) Distribution
#                 (x) File. Specify: Proprietary (JSON, HDF5)
#                 (  ) Repository
#         (x) Reproducibility
#         (x) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (x) Intention
# Analysis
#         (  ) Query
#                 (  ) Generic. Specify: __________
#                 (  ) Specific. Specify: __________
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (x) Comparison:
#                 (x) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Oxvig, Christian Schou and Arildsen, Thomas and Larsen, Torben. Storing Reproducible Results from Computational Experiments using Scientific Python Packages. Python in Science Conference, 2016
#
#
# TITLE: Michaelides et al. – Could you check if the following information is correct?
# TO: dtm@ecs.soton.ac.uk; Richard.Parker@bristol.ac.uk; C.Charlton@bristol.ac.uk; William.Browne@bristol.ac.uk; luc.moreau@kcl.ac.uk
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Danius T Michaelides, Richard Parker, Chris Charlton, William J Browne, and Luc Moreau,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include Michaelides et al. in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the Michaelides et al. paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (  ) Annotations
#                 Placement: (  ) Internal; (  ) External
#                 Extraction: (  ) Parseable; (  ) Execution
#                 Inclusiveness: (  ) Inclusive; (  ) Exclusive
#                 Target: (  ) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (  ) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (x) Overriding
#                 (  ) Post-Mortem
#                 (  ) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (x) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Proprietary (INPWR)
#         (x) Distribution
#                 (x) File. Specify: Proprietary (INPWR), Interoperable Format (PROV), Source (Blockly)
#                 (  ) Repository
#         (x) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (  ) Generic. Specify: __________
#                 (x) Specific. Specify: PROV
#         (x) Visualization
#                 Place: (  ) Internal; (x) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (x) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Michaelides, Danius T and Parker, Richard and Charlton, Chris and Browne, William J and Moreau, Luc. Intermediate Notation for Provenance and Workflow Reproducibility. International Provenance and Annotation Workshop, 2016
#
#
# TITLE: noWorkflow – Could you check if the following information is correct?
# TO: leomurta@ic.uff.br; vanessa@ic.uff.br; fchirigati@nyu.edu; dakoop@nyu.edu; juliana.freire@nyu.edu; jpimentel@ic.uff.br
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Leonardo Murta, Vanessa Braganholo, Fernando Chirigati, David Koop, Juliana Freire, João Felipe Nicolaci Pimentel, João Felipe Pimentel, and Joao Felipe Pimentel,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include noWorkflow in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the noWorkflow papers [1, 2, 3, 4, 5] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (  ) Annotations
#                 Placement: (  ) Internal; (  ) External
#                 Extraction: (  ) Parseable; (  ) Execution
#                 Inclusiveness: (  ) Inclusive; (  ) Exclusive
#                 Target: (  ) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (  ) Mandatory
#         (x) Execution
#                 (x) Passive Monitoring
#                 (x) Overriding
#                 (  ) Post-Mortem
#                 (  ) Instrumentation
#         (x) Deployment
#                 (x) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (x) Parsing
#                 When: (x) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: Relational Database (SQLite)
#                 (  ) Transient Memory
#                 (x) File. Specify: Content Database
#         (x) Distribution
#                 (x) File. Specify: Content Database, Logic File (Prolog)
#                 (  ) Repository
#         (x) Reproducibility
#         (x) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (x) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: SQL, Prolog
#                 (x) Specific. Specify: Functions, Web
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (x) Log; (  ) Data; (x) Process; (x) Combined
#                 Completeness: (  ) No Summarization; (x) Clustering; (x) Filtering
#         (x) Comparison:
#                 (  ) Data
#                 (x) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Murta, Leonardo and Braganholo, Vanessa and Chirigati, Fernando and Koop, David and Freire, Juliana. noWorkflow: capturing and analyzing provenance of scripts. International Provenance and Annotation Workshop, 2014
# [2] Pimentel, João Felipe Nicolaci and Braganholo, Vanessa and Murta, Leonardo and Freire, Juliana. Collecting and analyzing provenance on interactive notebooks: when IPython meets noWorkflow. Workshop on the Theory and Practice of Provenance, 2015
# [3] Pimentel, João Felipe and Freire, Juliana and Braganholo, Vanessa and Murta, Leonardo. Tracking and analyzing the evolution of provenance from scripts. International Provenance and Annotation Workshop, 2016
# [4] Pimentel, João Felipe and Freire, Juliana and Murta, Leonardo and Braganholo, Vanessa. Fine-grained provenance collection over scripts through program slicing. International Provenance and Annotation Workshop, 2016
# [5] Pimentel, Joao Felipe and Murta, Leonardo and Braganholo, Vanessa and Freire, Juliana. noWorkflow: a tool for collecting, analyzing, and managing provenance from python scripts. Very Large Data Bases, 2017
#
#
# TITLE: Provenance Curious – Could you check if the following information is correct?
# TO: mrhuq@ewubd.edu; p.m.g.apers@utwente.nl; andreas.wombacher@aureliusenterprise.com
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Mohammad Rezwanul Huq, Peter MG Apers, and Andreas Wombacher,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include Provenance Curious in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the Provenance Curious papers [1, 2, 3] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (  ) Internal; (x) External
#                 Extraction: (x) Parseable; (  ) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (x) Post-Mortem
#                 (  ) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (x) Definition
#                 How: (  ) Reading; (x) Parsing
#                 When: (x) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: Relational Database (SQLite)
#                 (  ) Transient Memory
#                 (  ) File. Specify: __________
#         (x) Distribution
#                 (x) File. Specify: Graph File (GraphML)
#                 (  ) Repository
#         (  ) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: SQL
#                 (x) Specific. Specify: Functions
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (x) Combined
#                 Completeness: (  ) No Summarization; (x) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Huq, Mohammad Rezwanul and Apers, Peter MG and Wombacher, Andreas. ProvenanceCurious: a tool to infer data provenance from scripts. International Conference on Extending Database Technology, 2013
# [2] Huq, Mohammad Rezwanul and Apers, Peter MG and Wombacher, Andreas. An inference-based framework to manage data provenance in Geoscience Applications. IEEE Transactions on Geoscience and Remote Sensing, 2013
# [3] Huq, Mohammad Rezwanul. An inference-based framework for managing data provenance. Thesis, 2013
#
#
# TITLE: pypet – Could you check if the following information is correct?
# TO: robert.meyer@ni.tu-berlin.de
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Robert Meyer,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include pypet in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the pypet papers [1, 2] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (x) Provenance
#                 Necessity: (x) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (x) Deployment
#                 (x) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (  ) Parsing
#                 When: (x) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Proprietary (HDF5)
#         (x) Distribution
#                 (x) File. Specify: Proprietary (HDF5)
#                 (  ) Repository
#         (  ) Reproducibility
#         (x) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (x) Intention
# Analysis
#         (  ) Query
#                 (  ) Generic. Specify: __________
#                 (  ) Specific. Specify: __________
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (x) Comparison:
#                 (x) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Meyer, Robert and Obermayer, Klaus. pypet: a python toolkit for simulations and numerical experiments. Neuroscience, 2015
# ...
# of features. We got these features based on the VCR paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (  ) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Log
#         (x) Distribution
#                 (  ) File. Specify: __________
#                 (  ) Repository
#         (x) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (  ) Generic. Specify: __________
#                 (x) Specific. Specify: Web
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (x) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (x) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Gavish, Matan and Donoho, David. A universal identifier for computational results. Procedia Computer Science, 2011
#
#
# TITLE: versuchung – Could you check if the following information is correct?
# TO: dietrich@sra.uni-hannover.de; lohmann@sra.uni-hannover.de
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Christian Dietrich and Daniel Lohmann,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include versuchung in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the versuchung paper [1] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (  ) Parseable; (x) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (  ) Post-Mortem
#                 (x) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (  ) Parsing
#                 When: (x) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: Relational Database (SQLite)
#                 (  ) Transient Memory
#                 (x) File. Specify: Content Database, Proprietary (Dict)
#         (x) Distribution
#                 (x) File. Specify: Content Database, Proprietary (Dict)
#                 (  ) Repository
#         (x) Reproducibility
#         (x) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (x) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: SQL
#                 (x) Specific. Specify: Functions
#         (  ) Visualization
#                 Place: (  ) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (  ) Filtering
#         (x) Comparison:
#                 (x) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Dietrich, Christian and Lohmann, Daniel. The dataref versuchung: Saving time through better internal repeatability. SIGOPS Operating Systems Review, 2015
#
#
# TITLE: WISE – Could you check if the following information is correct?
# TO: ruben.acuna@asu.edu; zoe.lacroix@asu.edu; bazzi@asu.edu; Jacques.Chomilier@impmc.jussieu.fr
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Ruben Acuña, Zoé Lacroix, Rida A Bazzi, and Jacques Chomilier,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include WISE in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the WISE papers [1, 2, 3, 4] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (  ) Annotations
#                 Placement: (  ) Internal; (  ) External
#                 Extraction: (  ) Parseable; (  ) Execution
#                 Inclusiveness: (  ) Inclusive; (  ) Exclusive
#                 Target: (  ) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (  ) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (x) Overriding
#                 (x) Post-Mortem
#                 (  ) Instrumentation
#         (x) Deployment
#                 (x) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (  ) Parsing
#                 When: (x) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Graph File (GraphML)
#         (x) Distribution
#                 (x) File. Specify: Graph File (GraphML)
#                 (  ) Repository
#         (  ) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (  ) Query
#                 (  ) Generic. Specify: __________
#                 (  ) Specific. Specify: __________
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (x) Process; (  ) Combined
#                 Completeness: (  ) No Summarization; (x) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Acuña, Ruben and Lacroix, Zoé and Bazzi, Rida A. Instrumentation and Trace Analysis for Ad-Hoc Python Workflows in Cloud Environments. International Conference on Cloud Computing, 2015
# [2] Acuña, Ruben. Understanding Legacy Workflows through Runtime Trace Analysis. Thesis, 2015
# [3] Acuña, Ruben and Chomilier, Jacques and Lacroix, Zoé. Managing and Documenting Legacy Scientific Workflows. Journal of Integrative Bioinformatics, 2015
# [4] Acuña, Ruben and Lacroix, Zoé. Extracting Semantics from Legacy Scientific Workflows. International Conference on Semantic Computing, 2016
#
#
# TITLE: YesWorkflow – Could you check if the following information is correct?
# TO: tmcphillips@absoluteflow.org; bowers@gonzaga.edu; Khalid.Belhajjame@dauphine.fr; ludaesch@illinois.edu
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Timothy McPhillips, Shawn Bowers, Khalid Belhajjame, and Bertram Ludäscher,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include YesWorkflow in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the YesWorkflow papers [1, 2] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (x) External
#                 Extraction: (x) Parseable; (  ) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (  ) Passive Monitoring
#                 (  ) Overriding
#                 (x) Post-Mortem
#                 (x) Instrumentation
#         (  ) Deployment
#                 (  ) Before
#                 (  ) During
#         (  ) Definition
#                 How: (  ) Reading; (  ) Parsing
#                 When: (  ) Static; (  ) Dynamic
# Management
#         (x) Storage:
#                 (  ) Database. Specify: __________
#                 (  ) Transient Memory
#                 (x) File. Specify: Interoperable Format (PROV), Logic File (Datalog), Graph File (GraphViz)
#         (x) Distribution
#                 (x) File. Specify: Interoperable Format (PROV), Logic File (Datalog), Graph File (GraphViz)
#                 (  ) Repository
#         (  ) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: Datalog
#                 (x) Specific. Specify: PROV
#         (x) Visualization
#                 Place: (x) Internal; (x) External
#                 Type: (  ) Log; (x) Data; (x) Process; (x) Combined
#                 Completeness: (x) No Summarization; (  ) Clustering; (  ) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] McPhillips, Timothy and Song, Tianhong and Kolisnik, Tyler and Aulenbach, Steve and Belhajjame, Khalid and Bocinsky, Kyle and Cao, Yang and Chirigati, Fernando and Dey, Saumen and Freire, Juliana and others. YesWorkflow: a user-oriented, language-independent tool for recovering workflow information from scripts. International Journal of Digital Curation, 2015
# [2] McPhillips, Timothy and Bowers, Shawn and Belhajjame, Khalid and Ludäscher, Bertram. Retrospective provenance without a runtime provenance recorder. Workshop on the Theory and Practice of Provenance, 2015
#
#
# TITLE: YW*NW – Could you check if the following information is correct?
# TO: leomurta@ic.uff.br; vanessa@ic.uff.br; jpimentel@ic.uff.br; tmcphillips@absoluteflow.org; Khalid.Belhajjame@dauphine.fr; ludaesch@illinois.edu
# CC: Juliana.freire@nyu.edu; leomurta@ic.uff.br; vanessa@ic.uff.br
#
# Dear Timothy McPhillips, Shawn Bowers, Khalid Belhajjame, and Bertram Ludäscher,
#
# We are currently working on a survey on provenance in scripts. In the survey, we propose a taxonomy for the
# state-of-the-art approaches in this research area and we characterize the approaches accordingly. We would
# also like to include YW*NW in this survey.
#
# To avoid any misunderstandings, we would kindly ask you to check and briefly comment on the following list
# of features. We got these features based on the YW*NW papers [1, 2, 3] but want to make sure we got everything
# correctly. We would highly appreciate if you could check our classification and make corrections when needed.
# Please send your answer before December 14, 2018. This would allow us to include your comments in our paper.
#
# Please, note that this is not a competition and we do not intend to rank the included systems.
#
# Collection
#         (x) Annotations
#                 Placement: (x) Internal; (  ) External
#                 Extraction: (x) Parseable; (  ) Execution
#                 Inclusiveness: (x) Inclusive; (  ) Exclusive
#                 Target: (x) Definition; (  ) Provenance
#                 Necessity: (  ) Optional; (x) Mandatory
#         (x) Execution
#                 (x) Passive Monitoring
#                 (x) Overriding
#                 (x) Post-Mortem
#                 (x) Instrumentation
#         (x) Deployment
#                 (x) Before
#                 (  ) During
#         (x) Definition
#                 How: (x) Reading; (x) Parsing
#                 When: (x) Static; (x) Dynamic
# Management
#         (x) Storage:
#                 (x) Database. Specify: Relational Database (SQLite)
#                 (  ) Transient Memory
#                 (x) File. Specify: Content Database, Logic File (Datalog), Graph File (GraphViz)
#         (x) Distribution
#                 (x) File. Specify: Logic File (Datalog), Graph File (GraphViz)
#                 (  ) Repository
#         (x) Reproducibility
#         (  ) Versioning
#                 (  ) Trial ID
#                 (  ) Sequence
#                 (  ) Intention
# Analysis
#         (x) Query
#                 (x) Generic. Specify: Datalog
#                 (  ) Specific. Specify: __________
#         (x) Visualization
#                 Place: (x) Internal; (  ) External
#                 Type: (  ) Log; (  ) Data; (  ) Process; (x) Combined
#                 Completeness: (  ) No Summarization; (  ) Clustering; (x) Filtering
#         (  ) Comparison:
#                 (  ) Data
#                 (  ) Provenance
#
# A glossary of the taxonomy describing each one of these categories can be found at https://joaofelipe.github.io/pins
#
# Many thanks in advance!
#
# All the best,
# João Felipe Pimentel
#
# References:
# [1] Dey, Saumen and Belhajjame, Khalid and Koop, David and Raul, Meghan and Ludäscher, Bertram. Linking prospective and retrospective provenance in scripts. Workshop on the Theory and Practice of Provenance, 2015
# [2] Pimentel, João Felipe and Dey, Saumen and McPhillips, Timothy and Belhajjame, Khalid and Koop, David and Murta, Leonardo and Braganholo, Vanessa and Ludäscher, Bertram. Yin & Yang: demonstrating complementary provenance from noWorkflow & YesWorkflow. International Provenance and Annotation Workshop, 2016
# [3] Pimentel, João Felipe and Dey, Saumen and McPhillips, Timothy and Belhajjame, Khalid and Koop, David and Murta, Leonardo and Braganholo, Vanessa and Ludäscher, Bertram. Yin & Yang Demo GitHub. Tech Report, 2016

# %%
bool(select(PROVENANCE, meta["annotations"]) == '  ' and meta["annotations"])
# Out:
# True
